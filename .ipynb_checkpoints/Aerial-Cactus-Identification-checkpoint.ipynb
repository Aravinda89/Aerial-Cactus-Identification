# %% [markdown]
# # Aerial-Cactus-Identification
# Determine whether an image contains a columnar cactus

# %% [markdown]
# ### Load and preprocessing data

# %%
import pandas as pd
import os
import random
from sklearn.utils import shuffle

# %%
ls aerial-cactus-identification_data/
# Out:
# sample_submission.csv* train/
# test/                  train.csv*

# %%
df = pd.read_csv("./aerial-cactus-identification_data/train.csv")
df.head()
# Out:
#                                      id  has_cactus
# 0  0004be2cfeaba1c0361d39e2b000257b.jpg           1
# 1  000c8a36845c0208e833c79c1bffedd1.jpg           1
# 2  000d1e9a533f62e55c289303b072733d.jpg           1
# 3  0011485b40695e9138e92d0b3fb55128.jpg           1
# 4  0014d7a11e90b62848904c1418fc8cf2.jpg           1

# %%
df['id'] = df['id'].apply(lambda x:os.path.join('./aerial-cactus-identification_data/train', x))

# %%
df1 = shuffle(df, random_state=10)
df1
# Out:
#                                                       id  has_cactus
# 59     ./aerial-cactus-identification_data/train/./ae...           1
# 7290   ./aerial-cactus-identification_data/train/./ae...           1
# 9804   ./aerial-cactus-identification_data/train/./ae...           1
# 8670   ./aerial-cactus-identification_data/train/./ae...           0
# 10606  ./aerial-cactus-identification_data/train/./ae...           0
# 4387   ./aerial-cactus-identification_data/train/./ae...           1
# 9043   ./aerial-cactus-identification_data/train/./ae...           1
# 1772   ./aerial-cactus-identification_data/train/./ae...           1
# 11728  ./aerial-cactus-identification_data/train/./ae...           1
# 1347   ./aerial-cactus-identification_data/train/./ae...           0
# 12758  ./aerial-cactus-identification_data/train/./ae...           1
# 17350  ./aerial-cactus-identification_data/train/./ae...           0
# 17487  ./aerial-cactus-identification_data/train/./ae...           1
# 8538   ./aerial-cactus-identification_data/train/./ae...           1
# 11449  ./aerial-cactus-identification_data/train/./ae...           1
# 14690  ./aerial-cactus-identification_data/train/./ae...           1
# 1471   ./aerial-cactus-identification_data/train/./ae...           1
# 3850   ./aerial-cactus-identification_data/train/./ae...           1
# 1816   ./aerial-cactus-identification_data/train/./ae...           1
# 6748   ./aerial-cactus-identification_data/train/./ae...           0
# 5661   ./aerial-cactus-identification_data/train/./ae...           1
# 11052  ./aerial-cactus-identification_data/train/./ae...           1
# 3986   ./aerial-cactus-identification_data/train/./ae...           1
# 15410  ./aerial-cactus-identification_data/train/./ae...           1
# 3904   ./aerial-cactus-identification_data/train/./ae...           1
# 16246  ./aerial-cactus-identification_data/train/./ae...           1
# 11495  ./aerial-cactus-identification_data/train/./ae...           0
# 13164  ./aerial-cactus-identification_data/train/./ae...           1
# 4049   ./aerial-cactus-identification_data/train/./ae...           0
# 13692  ./aerial-cactus-identification_data/train/./ae...           1
# ...                                                  ...         ...
# 8647   ./aerial-cactus-identification_data/train/./ae...           1
# 4300   ./aerial-cactus-identification_data/train/./ae...           1
# 13264  ./aerial-cactus-identification_data/train/./ae...           0
# 5627   ./aerial-cactus-identification_data/train/./ae...           1
# 14270  ./aerial-cactus-identification_data/train/./ae...           0
# 7197   ./aerial-cactus-identification_data/train/./ae...           1
# 11523  ./aerial-cactus-identification_data/train/./ae...           1
# 6176   ./aerial-cactus-identification_data/train/./ae...           1
# 11683  ./aerial-cactus-identification_data/train/./ae...           0
# 8739   ./aerial-cactus-identification_data/train/./ae...           1
# 11374  ./aerial-cactus-identification_data/train/./ae...           1
# 843    ./aerial-cactus-identification_data/train/./ae...           1
# 965    ./aerial-cactus-identification_data/train/./ae...           1
# 14889  ./aerial-cactus-identification_data/train/./ae...           1
# 3212   ./aerial-cactus-identification_data/train/./ae...           1
# 7932   ./aerial-cactus-identification_data/train/./ae...           1
# 6895   ./aerial-cactus-identification_data/train/./ae...           0
# 13693  ./aerial-cactus-identification_data/train/./ae...           1
# 7672   ./aerial-cactus-identification_data/train/./ae...           1
# 13455  ./aerial-cactus-identification_data/train/./ae...           1
# 10920  ./aerial-cactus-identification_data/train/./ae...           0
# 3335   ./aerial-cactus-identification_data/train/./ae...           1
# 16539  ./aerial-cactus-identification_data/train/./ae...           1
# 7257   ./aerial-cactus-identification_data/train/./ae...           1
# 13379  ./aerial-cactus-identification_data/train/./ae...           1
# 4377   ./aerial-cactus-identification_data/train/./ae...           0
# 4388   ./aerial-cactus-identification_data/train/./ae...           0
# 12488  ./aerial-cactus-identification_data/train/./ae...           1
# 8330   ./aerial-cactus-identification_data/train/./ae...           1
# 9907   ./aerial-cactus-identification_data/train/./ae...           1
#
# [17500 rows x 2 columns]
